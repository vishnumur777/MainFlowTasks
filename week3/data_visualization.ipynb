# %% [markdown]
# <h1 style="text-align: center"><b>Week 3 - Data Visualization</b></h1>

# %% [markdown]
# ## **_1. Import packages_**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as mc

# %% [markdown]
# ## **_2. Import dataset_**

# %%
df = pd.read_csv("householdtask3.csv")

# %%
df
# Out:
#     year  tot_hhs      own  own_wm  own_prop  own_wm_prop  prop_hhs   age  \
# 0   2008  1560859  1087580  574406      69.7         36.8     100.0  35.9
# 1   2008   185965    71256   39405      38.3         21.2      11.9  29.9
# 2   2008   312376   191470   48424      61.3         15.5      20.0  40.0
# 3   2008   312333   196203   84171      62.8         26.9      20.0  34.7
# 4   2008   312240   217657  141318      69.7         45.3      20.0  31.5
# ..   ...      ...      ...     ...       ...          ...       ...   ...
# 65  2020   352564   213893  119637      60.7         33.9      20.1  36.9
# 66  2020   350182   235256  141104      67.2         40.3      19.9  35.0
# 67  2020   351328   288779  187838      82.2         53.5      20.0  39.6
# 68  2020   329588   156459  107753      47.5         32.7      18.8  31.1
# 69  2020   388013   314154   38270      81.0          9.9      22.1  69.8
#
#     size  income  expenditure  eqv_income  eqv_exp
# ...

# %% [markdown]
# ## **_3. Scatter Plot_**

# %%
plt.scatter(df['year'],df['income'])
plt.title('Scatter Plot')
plt.show()

# %% [markdown]
# ## **_4. Scatter Plot ( colorbox )_**

# %%
plt.scatter(df['year'],df['expenditure'],c=df['income'])
plt.title('line chart')
plt.colorbar()
plt.show()

# %% [markdown]
# ## **_5. Line Chart_**

# %%
plt.plot(df['income'])
plt.plot(df['expenditure'])
plt.xlabel("Year")
plt.ylabel("Expenditure")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# ## **_6. Bar Chart_**

# %%
plt.bar(df.year,df.income)
plt.title("Bar Chart")
plt.xlabel("Year")
plt.ylabel("Income")
# Out:
# Text(0, 0.5, 'Income')

# %% [markdown]
# ## **_7. Histogram_**

# %%
plt.hist(df.income,bins=10)
# Out:
# (array([12., 14., 11., 14.,  7.,  4.,  4.,  1.,  2.,  1.]),
#  array([ 16747. ,  29739.5,  42732. ,  55724.5,  68717. ,  81709.5,
#          94702. , 107694.5, 120687. , 133679.5, 146672. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(8,6))
glue = df.corr()
yellow_blue_cmap = mc.LinearSegmentedColormap.from_list('yellow_blue', ['yellow', 'darkblue'])
sns.heatmap(glue,cmap=yellow_blue_cmap, annot=True)
plt.show()

# %% [markdown]
# <h1 style="text-align: center"><b><em>Thank You</em></b></h1>
